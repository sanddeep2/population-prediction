# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pop = pd.read_csv('C:\\Users\\Usharani\Desktop\population_project\population_data.csv', encoding='Latin-1')
pop
# Out:
#      year             state  population     %   male  female  sex ratio  \
# 0    2017   Jammu & Kashmir       12999  1.00   6837    6162        901
# 1    2017  Himachal Pradesh        7206  0.55   3654    3551        972
# 2    2017            Punjab       29380  2.25  15467   13913        900
# 3    2017       Uttarakhand       10884  0.83   5565    5319        956
# 4    2017           Haryana       27861  2.13  14793   13068        883
# ..    ...               ...         ...   ...    ...     ...        ...
# 105  2021    Andhra Pradesh       52787  3.87  26403   26384        999
# 106  2021         Karnataka       66845  4.90  33911   32934        971
# 107  2021            Kerala       35489  2.60  17043   18447       1082
# 108  2021        Tamil Nadu       76402  5.61  38165   38237       1002
# 109  2021         Telangana       37725  2.77  18978   18747        988
#
#     urban pop.  rural pop.  area(sq km)  pop. Density
# ...

# %%
pop.describe()
# Out:
#               year     population           %           male        female  \
# count   110.000000     110.000000  110.000000     110.000000     110.00000
# mean   2019.000000   59428.581818    4.453182   30674.663636   29255.50000
# std       1.420686   48674.323280    3.646239   25360.284850   23243.59947
# min    2017.000000    7206.000000    0.540000    3654.000000    3551.00000
# 25%    2018.000000   29176.750000    2.160000   15259.750000   14130.00000
# 50%    2019.000000   39689.000000    2.975000   21022.500000   22058.50000
# 75%    2020.000000   77048.500000    5.787500   39681.750000   38190.00000
# max    2021.000000  230907.000000   16.940000  120344.000000  110563.00000
#
#          sex ratio     rural pop.    area(sq km)  pop. Density
# count   110.000000     110.000000     110.000000     110.000000
# mean    976.345455   39418.390909  132366.409091    1074.818182
# std     257.826107   37825.936946   94991.276650    2711.159240
# ...

# %%
a=pop.groupby('year', as_index=False).sum()
a
# Out:
#    year  population      %    male  female  sex ratio  rural pop.  \
# 0  2017     1259070  96.41  660563  623684      20912      841279
# 1  2018     1298355  98.37  667703  630650      20924      865873
# 2  2019     1312462  98.36  674842  637624      20934      871116
# 3  2020     1326575  98.36  681981  644589      20941      876308
# 4  2021     1340682  98.35  689124  681558      23687      881447
#
#    area(sq km)  pop. Density
# 0      2912061          22827
# 1      2912061          23311
# 2      2912061          23673
# 3      2912061          24031
# 4      2912061          24388

# %%
plt.figure(figsize=(10,6))
plt.title("Total population of the year")

sns.barplot(x=a.index, y=a.population)
# Out:
# <AxesSubplot:title={'center':'Total population of the year'}, xlabel='year', ylabel='population'>

# %%
b=pop.groupby('state').mean()
b
# Out:
#                     year  population       %      male    female  sex ratio  \
# state
# Andhra Pradesh    2019.0     52221.0   3.914   26126.0   26095.0      998.8
# Assam             2019.0     34293.0   2.570   17471.6   16821.6      962.8
# Bihar             2019.0    119520.2   8.956   62196.4   57323.8      921.6
# Chhattisgarh      2019.0     28724.4   2.152   14410.0   14314.0      993.2
# Delhi             2019.0     19813.8   1.486   10569.8   15243.8     1422.0
# Gujarat           2019.0     62900.6   4.706   35588.4   32347.4      909.0
# Haryana           2019.0     28671.8   2.148   15207.8   13464.0      885.0
# Himachal Pradesh  2019.0      7300.0   0.546    3702.0    3597.6      972.0
# Jammu & Kashmir   2019.0     13203.2   0.990    6933.4    6270.0      904.2
# Jharkhand         2019.0     37402.8   2.800   19165.0   18237.8      951.6
# Karnataka         2019.0     65798.4   4.932   33373.6   32424.8      971.6
# ...

# %%
plt.figure(figsize=(10,8))
plt.title("statewise mean population")
sns.barplot(x=b.index, y=b.population)
plt.xticks(rotation=90)
plt.tight_layout()

# %%
# X=[2017,2018,2019,2020,2021]
X = a['year'].tolist()
Ygirls = a['female'].tolist()
# Ygirls = [20,25,30,20,30]
Zboys = a['male'].tolist()
# Zboys = [12,30,52,60,25]
  
X_axis = np.arange(len(X))
plt.figure(figsize=(16,8))
plt.bar(X_axis-0.2, Ygirls,0.4, label = 'Girls',color='b')
plt.bar(X_axis+0.2, Zboys,0.4, label = 'Boys',color='r')
  
plt.xticks(X_axis, X)
plt.xlabel("year")
plt.ylabel("population")
plt.title("male vs female")
plt.legend()
plt.show()

# %%
c= pop.groupby('state')
c.first()
# Out:
#                   year  population      %    male  female  sex ratio  \
# state
# Andhra Pradesh    2017       51655   3.96   25849   25806        998
# Assam             2017       33543   2.57   17100   16443        962
# Bihar             2017      115957   8.88   60381   55577        920
# Chhattisgarh      2017       27956   2.14   14026   13930        993
# Delhi             2017       19056   1.46   10177    8879        872
# Gujarat           2017       40907   3.13   34577   31507        911
# Haryana           2017       27861   2.13   14793   13068        883
# Himachal Pradesh  2017        7206   0.55    3654    3551        972
# Jammu & Kashmir   2017       12999   1.00    6837    6162        901
# Jharkhand         2017       36334   2.78   18629   17705        950
# Karnataka         2017       64752   4.96   32836   31916        972
# Kerala            2017       34761   2.66   16684   18077       1083
# ...

# %%
c.get_group('Delhi')
# Out:
#     year  state  population     %   male  female  sex ratio urban pop.  \
# 5   2017  Delhi       19056  1.46  10177    8879        872     18,824
# 27  2018  Delhi       19435  1.47  10373    9061        874     19,229
# 49  2019  Delhi       19814  1.49  10570    9244        875     19,634
# 71  2020  Delhi       20193  1.50  10766    9426        876     20,037
# 93  2021  Delhi       20571  1.51  10963   39609       3613     20,438
#
#     rural pop.  area(sq km)  pop. Density
# 5          232         1483          12850
# 27         206         1483          13105
# 49         180         1483          13361
# 71         156         1483          13616
# 93         133         1483          13871

# %%
from scipy import stats

x = a['year'].tolist()
y = a['population'].tolist()

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

print("relationship = ",r)

x1=myfunc(2022)
print("population in 2022 = ", x1)

x2=myfunc(2023)
print("population in 2023 = ", x2)

x3=myfunc(2024)
print("population in 2024 = ", x3)

x4=myfunc(2025)
print("population in 2025 = ", x4)
# Out:
# relationship =  0.9671118245842548
# population in 2022 =  1364862.0
# population in 2023 =  1384006.3999999985
# population in 2024 =  1403150.799999997
# population in 2025 =  1422295.1999999955

# %%
x = a['year'].tolist()
y = a['population'].tolist()

mymodel = np.poly1d(np.polyfit(x, y, 3))

myline = np.linspace(2017, 2025, 1500000)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

z1=mymodel(2022)
print("population in 2022 = ", z1)

z2=mymodel(2023)
print("population in 2023 = ", z2)

z3=mymodel(2024)
print("population in 2024 = ", z3)

z4=mymodel(2025)
print("population in 2025 = ", z4)
# Out:
# population in 2022 =  1374927.794921875
# population in 2023 =  1439378.7578125
# population in 2024 =  1546980.830078125
# population in 2025 =  1710320.00390625
